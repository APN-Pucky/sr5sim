// %%
#include <iostream>
#include "Rectangle.cpp"

using namespace std;

// %%
Rectangle rect(4, 7);
cout << rect.area() << endl;
// Out:
// input_line_6:2:2: error: type 'Rectangle' does not provide a call operator
//  rect(4, 7);
//  ^~~~
// input_line_6:3:24: error: reference to overloaded function could not be resolved; did you mean to call it?
// cout << rect.area() << endl;
//                        ^~~~
// /usr/include/c++/7/ostream:590:5: note: possible target for call
//     endl(basic_ostream<_CharT, _Traits>& __os)
//     ^
// /usr/include/c++/7/ostream:245:7: note: candidate function not viable: no overload of 'endl' matching 'const void *' for
//       1st argument
//       operator<<(const void* __p)
//       ^
// /usr/include/c++/7/system_error:217:5: note: candidate function not viable: no overload of 'endl' matching
//       'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /usr/include/c++/7/ostream:117:7: note: candidate function not viable: no overload of 'endl' matching
// ...
